# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
products = pd.read_csv("products.csv",index_col = 0)

# %%
pd.set_option('display.max_colwidth', -1)

# %%
products.head()
# Out:
#                 Brand                                      Product    Type  \
# 0  MAC Cosmetics       Studio Fix Powder Plus Foundation            Powder
# 1  bareMinerals        Bare Minerals ALL                            Powder
# 2  bareMinerals        Bare Minerals in 1.2, fairly light           Powder
# 3  L'Oreal Paris       Bare Naturale Powdered Mineral Foundation    Powder
# 4  Physicians Formula  Mineral Wear Talc-Free Mineral Loose Powder  Powder
#
#    Avg Rating  Number of Reviews  Percentage Would Buy Again
# 0  3.7         3938               0.66
# 1  2.9         3074               0.44
# 2  3.5         1152               0.59
# 3  3.5         1092               0.62
# 4  3.6         800                0.65

# %%
len(products)
# Out:
# 475

# %%
brand_list=products["Brand"].tolist()
product_list=products["Product"].tolist()

# %%
type(brand_list)
# Out:
# list

# %%
"""a=products.groupby("Brand")["Number of Reviews"].mean()
b=products.groupby("Brand")["Avg Rating"].mean()
c=products.groupby("Brand")["Percentage Would Buy Again"].mean()"""

# %%
"""Brand=pd.DataFrame({"NumberofReviews":a,"AvgRating":b,"Repurchase":c})
Brand.head()"""
# Out:
#                          NumberofReviews  AvgRating  Repurchase
# Brand
# AVEDA                    119.5            4.0        0.735
# Agnes B.                 124.0            2.7        0.430
# Alima Pure               451.0            4.0        0.720
# Almay                    109.0            2.3        0.260
# Anastasia Beverly Hills  29.0             3.2        0.440

# %%
Brand["Repurchase"].apply(lambda x: x/max(Brand["Repurchase"]))
# Out:
# Brand
# AVEDA                      0.798913
# Agnes B.                   0.467391
# Alima Pure                 0.782609
# Almay                      0.282609
# Anastasia Beverly Hills    0.478261
# Australis                  1.000000
# Avon                       0.679348
# Aziza                      0.847826
# BECCA                      0.641304
# Ben Nye                    0.945652
# Bite Beauty                0.706522
# Black Opal                 0.826087
# Bobbi Brown                0.608696
# Boots                      0.630435
# CHANEL                     0.668478
# CLARINS                    0.717391
# CLINIQUE                   0.673913
# COVERGIRL                  0.646739
# Cover FX                   0.673913
# DHC                        0.706522
# Dior                       0.684783
# EstÃ©e Lauder              0.695652
# Everyday Minerals          0.739130
# GOSH                       0.695652
# Giorgio Armani             0.913043
# GloMinerals                0.858696
# Hard Candy                 0.706522
# Hourglass Cosmetics        0.625000
# Iman                       0.793478
# It Cosmetics               0.717391
#                              ...
# Palladio Beauty            0.836957
# Peter Thomas Roth          0.521739
# Philosophy                 0.608696
# Physicians Formula         0.698370
# Pixi                       0.326087
# Prescriptives              0.755435
# Prestige                   0.793478
# Pure Luxe Cosmetics        0.777174
# REVLON                     0.565217
# RIMMEL                     0.641304
# SHISEIDO                   0.775362
# Sephora Collection         0.630435
# Sheer Cover                0.500000
# Silk Naturals              0.869565
# Skindinavia                0.771739
# Smashbox                   0.527174
# Sonia Kashuk               0.576087
# Stila                      0.684783
# TOM FORD                   0.684783
# Tarte Cosmetics            0.711957
# Too Faced                  0.699275
# Unlisted Brand             0.771739
# Urban Decay                0.597826
# Vichy                      0.706522
# Yves Saint Laurent         0.695652
# bareMinerals               0.571429
# benefit Cosmetics          0.516304
# e.l.f. Cosmetics           0.570652
# mark.                      0.750000
# shu uemura                 0.722826
# Name: Repurchase, Length: 88, dtype: float64

# %%
Brand["norm_reviews"]=Brand["NumberofReviews"].apply(lambda x: x/max(Brand["NumberofReviews"]))
Brand["norm_ratings"]=Brand["AvgRating"].apply(lambda x: x/max(Brand["AvgRating"]))
Brand["norm_repurchase"]=Brand["Repurchase"].apply(lambda x: x/max(Brand["Repurchase"]))

# %%
Brand.head()
# Out:
#                          NumberofReviews  AvgRating  Repurchase  norm_reviews  \
# Brand
# AVEDA                    119.5            4.0        0.735       0.108676
# Agnes B.                 124.0            2.7        0.430       0.112768
# Alima Pure               451.0            4.0        0.720       0.410149
# Almay                    109.0            2.3        0.260       0.099127
# Anastasia Beverly Hills  29.0             3.2        0.440       0.026373
#
#                          norm_ratings  norm_repurchase
# Brand
# AVEDA                    0.888889      0.798913
# Agnes B.                 0.600000      0.467391
# Alima Pure               0.888889      0.782609
# Almay                    0.511111      0.282609
# Anastasia Beverly Hills  0.711111      0.478261

# %%
engagement=[]
for p in Brand.itertuples():
    e_score = .2*p.norm_ratings+.5*p.norm_reviews+.3*p.norm_repurchase
    engagement.append(e_score)
Brand["engagement"]=engagement

# %%
percentage=Brand["engagement"].quantile(q=0.9)

# %%
top_brand=Brand[Brand["engagement"]>percentage]
top_brand.reset_index(level=0, inplace=True)
top_brand
# Out:
#                 Brand  NumberofReviews  AvgRating  Repurchase  norm_reviews  \
# 0  Alima Pure          451.00           4.000      0.720       0.410149
# 1  Everyday Minerals   473.50           3.800      0.680       0.430611
# 2  Jane Iredale        468.50           3.900      0.685       0.426064
# 3  MAC Cosmetics       1099.60          3.560      0.602       1.000000
# 4  Monistat            900.00           3.900      0.750       0.818479
# 5  Palladio Beauty     389.00           4.100      0.770       0.353765
# 6  Smashbox            642.75           3.250      0.485       0.584531
# 7  Yves Saint Laurent  899.00           3.700      0.640       0.817570
# 8  benefit Cosmetics   744.00           3.175      0.475       0.676610
#
#    norm_ratings  norm_repurchase  engagement
# 0  0.888889      0.782609         0.617635
# 1  0.844444      0.739130         0.605934
# 2  0.866667      0.744565         0.609735
# 3  0.791111      0.654348         0.854527
# 4  0.866667      0.815217         0.827138
# 5  0.911111      0.836957         0.610192
# 6  0.722222      0.527174         0.594862
# 7  0.822222      0.695652         0.781925
# 8  0.705556      0.516304         0.634307

# %%
Brand[Brand["engagement"]<percentage]["engagement"].plot(kind='bar',figsize=(12,6))

# %%
reviews = pd.read_csv("reviews.csv",index_col = 0)
reviews.head()
# Out:
#                              Product  Rating               Username  \
# 0  Studio Fix Powder Plus Foundation  4        Marlen86
# 1  Studio Fix Powder Plus Foundation  5        babypuggies
# 2  Studio Fix Powder Plus Foundation  4        ChristopherCupcakes
# 3  Studio Fix Powder Plus Foundation  4        congolesedoll
# 4  Studio Fix Powder Plus Foundation  5        manowaris
#
#                           Date    Age                          Skin  \
# 0   on  11/25/2018 4:35:00 PM   30-35  Oily, Fair-Medium, Not Sure
# 1   on  10/31/2018 9:42:00 AM   19-24  Combination, Medium, Warm
# 2   on  10/22/2018 1:28:00 PM   44-55  Combination, Medium, Neutral
# 3   on  10/9/2018 4:39:00 PM    19-24  Very Oily, Dark, Not Sure
# 4   on  10/9/2018 2:58:00 PM    19-24  Acne-prone, Fair, Neutral
#
#                       Hair   Eyes  \
# 0  Brown, Other, Other      Brown
# 1  Blond, Straight, Medium  Brown
# 2  Other, Straight, Medium  Green
# 3  Blond, Other, Other      Brown
# 4  Brown, Wavy, Coarse      Blue
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Review
# 0  Nice pigmented powder, especially to cover skin imperfections.
# 1  This has become my go-to foundation now! My oily dehydrated skin went haywire this year. All my trusted foundations, even purportedly hydrating Serum Foundation from The Ordinary, were too dry and cakey on me despite me rationing the tiniest amount. I began to avoid matte foundations like the plague.This foundation, however, gave me the most beautiful finish with medium coverage. Yes, it was matte, but for the first time in a while, it did not cake up or break down. I like to set it with plain rosewater for a more satin finish. The staying power was marvelous, lasting 12 hours without losing a tincture of coverage. Bonus points for being much easier to apply as opposed to a liquid foundation! It is also incredibly versatile.For lighter coverage, I use a flat top powder brush and buff it all over my face. For medium coverage, I pick up some power on the same brush, spritz a little rosewater on the brush, and buff it into my skin. This does not affect the finish of the product at all; just the coverage itself.If you're looking for oil control, this isn't your bag of chips. But then again, my skin is astoundingly oily, and I start to get shiny about 2 hours after application no matter what I use. So maybe it is just me, and not this powder.
# 2  This is an amazing powder foundation that leaves skin beautifully finished, matte and looking flawless. You can use this alone and it has a full coverage foundation or you can build it up and layer it over a liquid foundation to help set it and get more coverage. I'm a light skin and usually wear medium or natural medium foundations and I'm an NW 25 in this.
# 3  Amazing powder that keeps you MATTE and keeps the makeup in place
# 4  I bought this powder a lot. I love it. It has medium + coverage. It doesnât have the most natural look on me but it is ok. Donât use it around my eyes aa itâs makes me look 100

# %%
combo = ""

for data in reviews.itertuples():
    combo = data.Product+data.Age

# %%
reviews.head()
# Out:
#          Product  Rating               Username                         Date  \
# 0  MAC Cosmetics  4        Marlen86               on  11/25/2018 4:35:00 PM
# 1  MAC Cosmetics  5        babypuggies            on  10/31/2018 9:42:00 AM
# 2  MAC Cosmetics  4        ChristopherCupcakes    on  10/22/2018 1:28:00 PM
# 3  MAC Cosmetics  4        congolesedoll          on  10/9/2018 4:39:00 PM
# 4  MAC Cosmetics  5        manowaris              on  10/9/2018 2:58:00 PM
#
#      Age                          Skin                     Hair   Eyes  \
# 0  30-35  Oily, Fair-Medium, Not Sure   Brown, Other, Other      Brown
# 1  19-24  Combination, Medium, Warm     Blond, Straight, Medium  Brown
# 2  44-55  Combination, Medium, Neutral  Other, Straight, Medium  Green
# 3  19-24  Very Oily, Dark, Not Sure     Blond, Other, Other      Brown
# 4  19-24  Acne-prone, Fair, Neutral     Brown, Wavy, Coarse      Blue
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Review  \
# 0  Nice pigmented powder, especially to cover skin imperfections.
# 1  This has become my go-to foundation now! My oily dehydrated skin went haywire this year. All my trusted foundations, even purportedly hydrating Serum Foundation from The Ordinary, were too dry and cakey on me despite me rationing the tiniest amount. I began to avoid matte foundations like the plague.This foundation, however, gave me the most beautiful finish with medium coverage. Yes, it was matte, but for the first time in a while, it did not cake up or break down. I like to set it with plain rosewater for a more satin finish. The staying power was marvelous, lasting 12 hours without losing a tincture of coverage. Bonus points for being much easier to apply as opposed to a liquid foundation! It is also incredibly versatile.For lighter coverage, I use a flat top powder brush and buff it all over my face. For medium coverage, I pick up some power on the same brush, spritz a little rosewater on the brush, and buff it into my skin. This does not affect the finish of the product at all; just the coverage itself.If you're looking for oil control, this isn't your bag of chips. But then again, my skin is astoundingly oily, and I start to get shiny about 2 hours after application no matter what I use. So maybe it is just me, and not this powder.
# 2  This is an amazing powder foundation that leaves skin beautifully finished, matte and looking flawless. You can use this alone and it has a full coverage foundation or you can build it up and layer it over a liquid foundation to help set it and get more coverage. I'm a light skin and usually wear medium or natural medium foundations and I'm an NW 25 in this.
# 3  Amazing powder that keeps you MATTE and keeps the makeup in place
# 4  I bought this powder a lot. I love it. It has medium + coverage. It doesnât have the most natural look on me but it is ok. Donât use it around my eyes aa itâs makes me look 100
#
#               prod_age
# 0  30-35 MAC Cosmetics
# 1  19-24 MAC Cosmetics
# 2  44-55 MAC Cosmetics
# 3  19-24 MAC Cosmetics
# 4  19-24 MAC Cosmetics

# %%
reviews["Age"].unique()
# Out:
# array(['30-35', '19-24', '44-55', '56 & Over', '36-43', '25-29',
#        '18 & Under', 'Unknown'], dtype=object)

# %%
reviews.replace(product_list,brand_list,inplace=True)

# %%
reviews["prod_age"]=reviews["Age"]+" "+reviews["Product"]

# %%
top_reviews=reviews[reviews["Product"].isin(top_brand["Brand"])==True]

# %%
len(top_reviews)
# Out:
# 15568

# %% [markdown]
# # lift

# %%
age=reviews[reviews["Age"]!='Unknown']
age_list=age["Age"].unique()

# %%
unique_products=products["Brand"].unique().tolist()[:7]
top_reviews=reviews[reviews["Product"].isin(unique_products)==True]

# %%
unique_products
product_combos = []
for i in range (len(unique_products)):
    for j in range (len(age_list)):
        product_combo = (unique_products[i], age_list[j])
        product_combos.append(product_combo)

# %%
unique_products
# Out:
# ['MAC Cosmetics',
#  'bareMinerals',
#  "L'Oreal Paris",
#  'Physicians Formula',
#  'Jane Iredale',
#  'Maybelline New York',
#  'Laura Mercier']

# %%
top_reviews.shape
# Out:
# (21393, 10)

# %%
product_combo_dict = {}
for bc in product_combos:
    product_combo_dict[bc] = 0

# %%
for bc in product_combos:
    for c in reviews["prod_age"]:
        product1 = bc[0]
        product2 = bc[1]
        if product1 in c and product2 in c:
            product_combo_dict[bc] += 1

# %%
product_combo_dict
# Out:
# {('MAC Cosmetics', '30-35'): 695,
#  ('MAC Cosmetics', '19-24'): 2147,
#  ('MAC Cosmetics', '44-55'): 148,
#  ('MAC Cosmetics', '56 & Over'): 16,
#  ('MAC Cosmetics', '36-43'): 371,
#  ('MAC Cosmetics', '25-29'): 1299,
#  ('MAC Cosmetics', '18 & Under'): 749,
#  ('bareMinerals', '30-35'): 1358,
#  ('bareMinerals', '19-24'): 2489,
#  ('bareMinerals', '44-55'): 429,
#  ('bareMinerals', '56 & Over'): 79,
#  ('bareMinerals', '36-43'): 807,
#  ('bareMinerals', '25-29'): 1657,
#  ('bareMinerals', '18 & Under'): 719,
#  ("L'Oreal Paris", '30-35'): 424,
#  ("L'Oreal Paris", '19-24'): 865,
#  ("L'Oreal Paris", '44-55'): 240,
#  ("L'Oreal Paris", '56 & Over'): 63,
#  ("L'Oreal Paris", '36-43'): 295,
#  ("L'Oreal Paris", '25-29'): 485,
#  ("L'Oreal Paris", '18 & Under'): 395,
#  ('Physicians Formula', '30-35'): 135,
#  ('Physicians Formula', '19-24'): 355,
#  ('Physicians Formula', '44-55'): 50,
#  ('Physicians Formula', '56 & Over'): 16,
#  ('Physicians Formula', '36-43'): 81,
#  ('Physicians Formula', '25-29'): 191,
#  ('Physicians Formula', '18 & Under'): 188,
#  ('Jane Iredale', '30-35'): 224,
#  ('Jane Iredale', '19-24'): 186,
#  ('Jane Iredale', '44-55'): 96,
#  ('Jane Iredale', '56 & Over'): 25,
#  ('Jane Iredale', '36-43'): 146,
#  ('Jane Iredale', '25-29'): 214,
#  ('Jane Iredale', '18 & Under'): 20,
#  ('Maybelline New York', '30-35'): 186,
#  ('Maybelline New York', '19-24'): 628,
#  ('Maybelline New York', '44-55'): 86,
#  ('Maybelline New York', '56 & Over'): 29,
#  ('Maybelline New York', '36-43'): 132,
#  ('Maybelline New York', '25-29'): 267,
#  ('Maybelline New York', '18 & Under'): 519,
#  ('Laura Mercier', '30-35'): 316,
#  ('Laura Mercier', '19-24'): 483,
#  ('Laura Mercier', '44-55'): 82,
#  ('Laura Mercier', '56 & Over'): 20,
#  ('Laura Mercier', '36-43'): 209,
#  ('Laura Mercier', '25-29'): 408,
#  ('Laura Mercier', '18 & Under'): 81}

# %%
unique_products_dict = {}
for b in unique_products:
    for c in reviews["prod_age"]:
        if b in c:
            if b in unique_products_dict:
                unique_products_dict[b] += 1
            else:
                unique_products_dict[b] = 1

# %%
age_dict = {}
for b in age_list:
    for c in reviews["prod_age"]:
        if b in c:
            if b in age_dict:
                age_dict[b] += 1
            else:
                age_dict[b] = 1

# %%
age_dict
# Out:
# {'30-35': 7884,
#  '19-24': 16124,
#  '44-55': 3053,
#  '56 & Over': 652,
#  '36-43': 5136,
#  '25-29': 10735,
#  '18 & Under': 5730}

# %%
unique_products_dict
# Out:
# {'MAC Cosmetics': 5497,
#  'bareMinerals': 7643,
#  "L'Oreal Paris": 2789,
#  'Physicians Formula': 1033,
#  'Jane Iredale': 937,
#  'Maybelline New York': 1854,
#  'Laura Mercier': 1640}

# %%
tot_number = top_reviews.shape[0]

# %%
tot_number
# Out:
# 21393

# %%
lifts_dict = {}
for a in product_combo_dict:
    if a[0] == a[1]:
        lift = 0
    else:
        combo_count = product_combo_dict[a]
        attri1_count = unique_products_dict[a[0]]
        attri2_count = age_dict[a[1]]
        lift = (tot_number * combo_count) / (attri1_count * attri2_count)
    lifts_dict[a] = lift

# %%
age_dict
# Out:
# {'30-35': 7884,
#  '19-24': 16124,
#  '44-55': 3053,
#  '56 & Over': 652,
#  '36-43': 5136,
#  '25-29': 10735,
#  '18 & Under': 5730}

# %%
matrix = []
row = -1
current_attri = ''
for combo in lifts_dict:
    attri = combo[0]
    lift = lifts_dict[combo]
    if attri == current_attri:
        matrix[row].append(lift)
    else:
        row += 1
        current_attri = attri
        matrix.append([])
        matrix[row].append(lift)

# %%
simi = pd.DataFrame(matrix, columns=unique_products, index=age_list)

# %%
simi
# Out:
#             MAC Cosmetics  bareMinerals  L'Oreal Paris  Physicians Formula  \
# 30-35       0.343071       0.518209      0.188660       0.095503
# 19-24       0.482126       0.432076      0.393313       0.339146
# 44-55       0.412518       0.411497      0.602987       0.741167
# 56 & Over   0.354616       0.455960      0.339168       0.508211
# 36-43       0.648684       0.263374      0.717921       0.875436
# 25-29       0.272225       0.449416      0.325038       0.513230
# 18 & Under  0.522839       0.390753      0.350360       0.400138
#
#             Jane Iredale  Maybelline New York  Laura Mercier
# 30-35       0.281122      0.470926             0.508713
# 19-24       0.439801      0.432044             0.351222
# 44-55       0.440575      0.346548             0.528769
# 56 & Over   0.326611      0.368470             0.679477
# 36-43       0.649023      0.455139             0.079691
# 25-29       0.296559      0.286993             1.045141
# 18 & Under  0.530822      0.495777             0.184399

# %%
#dissimilarity
dis=matrix
for i in range (len(matrix)):
    for j in range (len(matrix[i])):
        if matrix[i][j] != 0:
            dis[i][j] = 1/matrix[i][j]

# %%
dissimilarity = pd.DataFrame(dis, columns=unique_products, index=age_list)

# %%
dissimilarity
# Out:
#             MAC Cosmetics  bareMinerals  L'Oreal Paris  Physicians Formula  \
# 30-35       2.914848       1.929722      5.300528       10.470843
# 19-24       2.074145       2.314409      2.542504       2.948578
# 44-55       2.424139       2.430152      1.658412       1.349223
# 56 & Over   2.819950       2.193174      2.948393       1.967688
# 36-43       1.541582       3.796888      1.392911       1.142288
# 25-29       3.673430       2.225108      3.076567       1.948443
# 18 & Under  1.912633       2.559162      2.854205       2.499135
#
#             Jane Iredale  Maybelline New York  Laura Mercier
# 30-35       3.557174      2.123474             1.965744
# 19-24       2.273755      2.314577             2.847200
# 44-55       2.269759      2.885607             1.891186
# 56 & Over   3.061742      2.713922             1.471721
# 36-43       1.540778      2.197132             12.548521
# 25-29       3.372012      3.484407             0.956809
# 18 & Under  1.883870      2.017038             5.423027

# %%
sns.heatmap(simi, linewidth=0.5,cmap = 'GnBu', center=0.7)

# %% [markdown]
# ### Plot MDS Map

# %%
from sklearn import manifold
from sklearn.metrics import euclidean_distances
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
fig = plt.figure(1)
ax = plt.axes([0., 0., 1., 1.])

s = 100

plt.scatter(pos[:, 0], pos[:, 1], color='turquoise', s=s, lw=0, label='MDS')
plt.legend(scatterpoints=1, loc='best', shadow=False)

for label, x, y in zip(unique_products, pos[:, 0], pos[:, 1]):
    plt.annotate(
        label,
        xy = (x, y), xytext = (-20, 20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-185-14c758840907> in <module>()
#       4 s = 100
#       5
# ----> 6 plt.scatter(pos[:, 0], pos[:, 1], color='turquoise', s=s, lw=0, label='MDS')
#       7 plt.legend(scatterpoints=1, loc='best', shadow=False)
#       8
#
# NameError: name 'pos' is not defined

# %% [markdown]
# # LDA

# %%
import re

import nltk
nltk.download('words')
from nltk.corpus import stopwords
from nltk.corpus import words
stopwords = stopwords.words('english')[:]
text=top_reviews["Review"].tolist()
# Out:
# [nltk_data] Downloading package words to /Users/claire/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
v=set(nltk.corpus.words.words())

# %%
words=[]
t = ''
for i in text:
    word=re.compile(r'[^a-zA-Z]').split(i)
    a=[]
    for i in word:
        if i in v:
            if i not in stopwords and len(i)>2 :
                a.append(i)
    a=" ".join(a) 
    doc = nlp(a)
    for token in doc:
        t = t+" "+token.lemma_
    words.append(t)

# %%
words[:5]

# %%
import spacy
nlp = spacy.load('en')

doc = nlp("Apples apple and oranges orange are similar. Boots and hippos aren't.")
t = ''
for token in doc:
    t = t+' '+token.lemma_
print(t)
    #doc = doc.repalce(token, token.lemma_)
# Out:
#   apple apple and orang orange be similar . boot and hippo be not .

# %%
type(doc)
# Out:
# str

# %%
len(words)
# Out:
# 15568

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer,TfidfTransformer
# init count vectorizer
vectorizer = CountVectorizer(analyzer='word',       
                             stop_words='english',             # remove stop words
                             lowercase=True,                   # convert all words to lowercase
                            )

# %%
word_vectorized = vectorizer.fit_transform(words)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation(n_components = 5, random_state = 0)

# %%
lda.fit(word_vectorized)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7, learning_method=None,
#              learning_offset=10.0, max_doc_update_iter=100, max_iter=10,
#              mean_change_tol=0.001, n_components=5, n_jobs=1,
#              n_topics=None, perp_tol=0.1, random_state=0,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
# column names
topicnames = ["Topic" + str(i) for i in range(1, lda.n_components + 1)]

# weights of each keyword in each topic

# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(lda.components_.T)

# Assign Column and Index
df_topic_keywords.index = vectorizer.get_feature_names()
df_topic_keywords.columns = topicnames

# View
df_topic_keywords
# Out:
#                  Topic1    Topic2      Topic3      Topic4     Topic5
# aback        0.214552    0.562658  0.230470    0.205135    1.871418
# abandon      0.207925    2.267863  0.205549    0.206907    0.212045
# abandoned    1.508657    0.200009  0.203321    0.294334    0.231567
# abide        0.200001    0.200008  0.200270    0.689502    0.343697
# ability      20.499086   0.205019  0.205869    3.364958    13.395875
# able         111.613970  0.509867  63.915574   143.895087  33.322575
# abnormal     0.212585    0.212969  3.281953    0.200463    0.201617
# abolish      0.203847    0.202088  0.201169    0.202467    1.037562
# abominable   0.202599    0.828770  0.200000    0.200535    0.201574
# abrasive     0.207173    0.200033  0.200530    1.405329    0.207880
# abroad       0.201770    5.331550  0.211013    0.202511    0.203223
# absence      12.342325   0.202273  0.572798    0.203699    0.207396
# absent       0.204204    3.339416  0.206386    0.201969    0.200004
# absolute     0.206418    3.726044  45.010767   50.023661   0.207257
# absolutely   129.332896  0.205899  298.729910  210.810547  0.206611
# absorb       0.207337    0.204235  49.822484   46.994284   0.269082
# absorbed     25.445250   0.207859  28.974490   0.205219    0.205749
# absorbent    0.203222    2.328011  0.200453    0.203407    0.200617
# absorber     0.216116    0.212087  0.200869    0.878030    0.203059
# absorbing    0.216118    0.229931  0.213748    58.456032   0.203514
# absorption   0.203690    4.848037  0.200911    0.202702    0.202351
# absurd       0.202073    0.204811  0.206662    0.205399    2.656536
# absurdly     0.203638    2.335524  0.203746    0.202226    0.200004
# abundance    0.888784    0.200013  0.202196    0.204165    0.200007
# abundant     0.201151    0.202880  1.129115    0.200867    0.200007
# abuse        0.206830    1.178364  0.205031    0.200872    0.203013
# academic     0.203295    1.284303  0.200998    0.206059    0.200004
# accelerate   1.544538    0.200010  0.207404    0.205680    0.202837
# accelerated  0.218204    0.202638  0.212845    2.498526    0.200013
# accent       0.202588    0.201297  0.201888    4.002966    0.206475
# ...               ...         ...       ...         ...         ...
# yellowing    0.204636    0.200007  0.200001    0.203632    0.964875
# yellowish    0.202015    0.202586  0.202113    0.203660    30.815330
# yellowness   0.201715    0.200433  0.200650    0.204879    3.591205
# yellows      0.201723    0.201464  0.200970    0.201603    4.058540
# yellowy      16.949568   0.202215  0.201522    0.209469    0.209048
# yen          0.202763    0.203259  0.201124    0.201317    0.998065
# yep          4.933184    0.203316  0.201527    0.202489    0.203627
# yes          68.007479   0.206306  103.117517  44.651282   0.206562
# yesterday    88.796889   0.203626  4.082402    0.203277    0.204047
# yield        1.620622    0.210203  0.211433    0.212673    0.200019
# yoga         1.814740    0.211803  0.201069    0.202132    0.207969
# york         0.203282    0.200022  2.773032    0.202338    0.208347
# young        24.410876   0.204857  0.205283    18.929705   0.205633
# younger      0.207739    0.207317  70.211907   0.213761    0.216108
# youth        0.202178    7.377202  0.204563    0.201500    0.203715
# youthful     2.376867    0.205182  4.757178    4.403275    13.634817
# youve        4.173571    0.203508  0.204377    0.207620    0.201829
# yoy          0.207763    0.200052  1.507522    0.200007    0.200028
# yuck         35.519349   0.204834  0.205941    0.203508    0.201289
# yucky        21.100980   5.542210  0.207024    0.205743    0.202081
# yummy        0.205707    0.203601  3.140306    0.209342    0.214195
# zealously    0.200002    0.200013  0.201941    0.864079    0.200007
# zen          0.267118    0.222037  1.695876    0.216069    0.206076
# zero         18.649283   0.203585  22.795323   7.574815    0.206460
# zinc         0.204498    0.205958  0.203160    0.201704    78.419765
# zink         0.205016    0.200610  0.200692    0.200311    2.717032
# zip          6.595530    0.206499  0.203644    0.203180    0.210376
# zombie       0.209017    0.200619  0.206772    0.200591    5.028183
# zone         521.334833  0.203957  226.642704  328.838652  0.203090
# zoo          0.221123    0.200026  0.201946    2.636217    0.203345
#
# [8496 rows x 5 columns]

# %%
# throw this onto a csv
df_topic_keywords.to_csv("wordstotopics2.csv")

# %%
topic1 = pd.DataFrame(df_topic_keywords.sort_values(by = ['Topic1'], ascending = False).head(10).index.values)
topic1.columns = ["Topic1"]
topic1
# Out:
#        Topic1
# 0  skin
# 1  oily
# 2  face
# 3  day
# 4  oil
# 5  product
# 6  acne
# 7  tried
# 8  foundation
# 9  try

# %%
topic2 = pd.DataFrame(df_topic_keywords.sort_values(by = ['Topic2'], ascending = False).head(10).index.values)
topic2.columns = ["Topic2"]
topic2
# Out:
#     Topic2
# 0  pump
# 1  place
# 2  visible
# 3  sun
# 4  glide
# 5  silk
# 6  low
# 7  benefit
# 8  badly
# 9  bother

# %%
# topic 3
topic3 = pd.DataFrame(df_topic_keywords.sort_values(by = ['Topic3'], ascending = False).head(10).index.values)
topic3.columns = ["Topic3"]
topic3
# Out:
#        Topic3
# 0  primer
# 1  product
# 2  like
# 3  skin
# 4  really
# 5  foundation
# 6  face
# 7  use
# 8  make
# 9  feel

# %% [markdown]
# We decided to name this topic "ecosystem"

# %%
# topic 4
topic4 = pd.DataFrame(df_topic_keywords.sort_values(by = ['Topic4'], ascending = False).head(10).index.values)
topic4.columns = ["Topic4"]
topic4
# Out:
#        Topic4
# 0  foundation
# 1  skin
# 2  powder
# 3  use
# 4  coverage
# 5  look
# 6  like
# 7  product
# 8  love
# 9  brush

# %% [markdown]
# We decided to name this topic "Wildlife"

# %%
# topic 5
topic5 = pd.DataFrame(df_topic_keywords.sort_values(by = ['Topic5'], ascending = False).head(10).index.values)
topic5.columns = ["Topic5"]
topic5
# Out:
#       Topic5
# 0  color
# 1  shade
# 2  match
# 3  light
# 4  mineral
# 5  yellow
# 6  dark
# 7  pink
# 8  colors
# 9  concealer
